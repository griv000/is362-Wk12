# %% [markdown]
# ## IS 362 - Week 12 Assignment
#
# The New York Times web site provides a rich set of APIs, as described here: http://developer.nytimes.com/
#
# Your task is to choose one of the New York Times APIs, construct an interface in Python to read in the JSON data, and transform it into a pandas DataFrame.

# %%
# import modules

import pandas as pd
import json
import urllib
from pandas.io.json import json_normalize

# %% [markdown]
# The API I've selected is reviews of Stephen King books:

# %%
# Accessing NY Times API
api_key = 'XCGL7FHEFmSNTgtbWquAjf1JOO6g8DkV'
url = 'https://api.nytimes.com/svc/books/v3/reviews.json?author=Stephen+King&api-key='
string = url+api_key
response = str(urllib.request.urlopen(string).read(), 'utf-8')

# Read JSON data
nytimes = pd.read_json(response)
nytimes
# Out:
#    status                                          copyright  num_results  \
# 0      OK  Copyright (c) 2019 The New York Times Company....           66
# 1      OK  Copyright (c) 2019 The New York Times Company....           66
# 2      OK  Copyright (c) 2019 The New York Times Company....           66
# 3      OK  Copyright (c) 2019 The New York Times Company....           66
# 4      OK  Copyright (c) 2019 The New York Times Company....           66
# ..    ...                                                ...          ...
# 61     OK  Copyright (c) 2019 The New York Times Company....           66
# 62     OK  Copyright (c) 2019 The New York Times Company....           66
# 63     OK  Copyright (c) 2019 The New York Times Company....           66
# 64     OK  Copyright (c) 2019 The New York Times Company....           66
# 65     OK  Copyright (c) 2019 The New York Times Company....           66
#
#                                               results
# ...

# %% [markdown]
# The revelant information is in the results column, so we'll want to pull from that:

# %%
# creating dataframe
data = json.loads(response)
most_viewed = json_normalize(data['results'])
most_viewed
# Out:
#                                                   url publication_dt  \
# 0   http://www.nytimes.com/2011/11/13/books/review...     2011-11-13
# 1   http://www.nytimes.com/2011/10/31/books/stephe...     2011-10-31
# 2   http://www.nytimes.com/2004/01/04/books/the-qu...     2004-01-04
# 3   http://www.nytimes.com/1993/10/24/books/in-sho...     1993-10-24
# 4   http://www.nytimes.com/2001/11/04/books/books-...     2001-11-04
# ..                                                ...            ...
# 61  http://www.nytimes.com/2016/06/12/books/review...     2016-06-12
# 62  https://www.nytimes.com/2018/05/22/books/revie...     2018-05-22
# 63  https://www.nytimes.com/2018/10/26/books/revie...     2018-10-26
# 64  https://www.nytimes.com/2019/09/08/books/revie...     2019-09-08
# 65  https://www.nytimes.com/2019/09/10/books/revie...     2019-09-10
#
#                      byline                  book_title   book_author  \
# ...
